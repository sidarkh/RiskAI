# %% [markdown]
# # RiskAI – Modelltraining und -vergleich
#
# In dieser Phase trainieren wir verschiedene Machine-Learning-Modelle zur Erkennung von Kreditkartenbetrug.
# Wir vergleichen:
# 1. Logistische Regression
# 2. Entscheidungsbäume
# 3. Random Forest (später)
# 4. Gradient Boosting / XGBoost (später)

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, auc

X_train = pd.read_csv("../data/processed/X_train_scaled.csv")
X_test = pd.read_csv("../data/processed/X_test_scaled.csv")
y_train = pd.read_csv("../data/processed/y_train.csv").values.ravel()
y_test = pd.read_csv("../data/processed/y_test.csv").values.ravel()

print(f"Trainingsdaten: {X_train.shape} | Testdaten: {X_test.shape}")
# Out:
# Trainingsdaten: (226980, 32) | Testdaten: (56746, 32)

# %%
# 1. Baseline Logistische Regression (Standard, ohne Gewichtung)
lr_baseline = LogisticRegression(max_iter=1000, random_state=42)
lr_baseline.fit(X_train, y_train)

# 2. Logistische Regression mit ausbalancierten Klassengewichten
lr_balanced = LogisticRegression(max_iter=1000, class_weight="balanced", random_state=42)
lr_baseline.fit(X_train, y_train)

print("Beide logistischen Regressionsmodelle erfolgreich trainiert!")
# Out:
# Beide logistischen Regressionsmodelle erfolgreich trainiert!

# %%
# Wir vergleichen und bewerten jetzt unsere Modelle
y_pred_baseline = lr_baseline.predict(X_test)
y_pred_balanced = lr_balanced.predict(X_test)


print("=== BASELINE MODELL (Ohne Klassengewichte) ===")
print(classification_report(y_test, y_pred_baseline))
print("Konfusionsmatrix:")
print(confusion_matrix(y_test, y_pred_baseline))


print("=== BASELINE MODELL (Mit class_weight=balanced) ===")
print(classification_report(y_test, y_pred_balanced))
print("Konfusionsmatrix:")
print(confusion_matrix(y_test, y_pred_balanced))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Wir vergleichen und bewerten jetzt unsere Modelle
#       2 y_pred_baseline = lr_baseline.predict(X_test)
# ----> 3 y_pred_balanced = lr_balanced.predict(X_test)
#       6 print("=== BASELINE MODELL (Ohne Klassengewichte) ===")
#       7 print(classification_report(y_test, y_pred_baseline))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_base.py:375, in LinearClassifierMixin.predict(self, X)
#     361 """
#     362 Predict class labels for samples in X.
#     363
#    (...)
#     372     Vector containing the class labels for each sample.
#     373 """
#     374 xp, _ = get_namespace(X)
# --> 375 scores = self.decision_function(X)
#     376 if len(scores.shape) == 1:
#     377     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_base.py:349, in LinearClassifierMixin.decision_function(self, X)
#     330 def decision_function(self, X):
#     331     """
#     332     Predict confidence scores for samples.
#     333
#    (...)
#     347         this class would be predicted.
#     348     """
# --> 349     check_is_fitted(self)
#     350     xp, _ = get_namespace(X)
#     352     X = validate_data(self, X, accept_sparse="csr", reset=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:1754, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1751     return
#    1753 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1754     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
